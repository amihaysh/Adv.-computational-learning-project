# %% [markdown]
#  put a zip file ATEPP-alignment.zip outside all of the files
#
#  after install libriries move the data file outside in content
#
#  in the end put the model_best_1000_7.ckpt in the right place
#
#  epochs=10

# %%
# Unzip the ATEPP-alignment.zip file into /content/data/
# !unzip -q /content/ATEPP-alignment.zip -d /content/data/

# %%
# !git clone https://github.com/tangjjbetsy/PID-CNN.git
# %cd PID-CNN
# Out:
# Cloning into 'PID-CNN'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 57 (delta 26), reused 44 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (57/57), 304.58 KiB | 1.14 MiB/s, done.
# Resolving deltas: 100% (26/26), done.
# /content/PID-CNN

# %%
# !pip install pretty_midi pytorch-lightning torchmetrics wandb numpy matplotlib seaborn scikit-learn pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 52.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 45.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.3/927.3 kB 45.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 67.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# ...

# %%
import os

# Define the source and destination folder names (adjust as needed)
src = '/content/data/ATEPP-alignment/Ludwig_van_Beethoven/Piano_Sonata_No._8_in_C_Minor,_Op._13_"Pathétique"'
dst = '/content/data/ATEPP-alignment/Ludwig_van_Beethoven/Piano_Sonata_No._8_in_C_Minor,_Op._13_"Pathétique"'

# Rename the folder
os.rename(src, dst)
print(f"Renamed folder from\n{src}\nto\n{dst}")
# Out:
# Renamed folder from
# /content/data/ATEPP-alignment/Ludwig_van_Beethoven/Piano_Sonata_No._8_in_C_Minor,_Op._13_"Pathétique"
# to
# /content/data/ATEPP-alignment/Ludwig_van_Beethoven/Piano_Sonata_No._8_in_C_Minor,_Op._13_"Pathétique"

# %%
# !mkdir -p /content/PID-CNN/data
# Create the target folder if it doesn't exist
# !mkdir -p /content/data

# %%
# !python data_preprocess.py --mode align --slice_len 1000 -s -o -S --path_to_dataset_csv /content/data/ID-1000.csv --data_folder /content/data/ATEPP-alignment/
# Out:
# ----------------Start Processing--------------------
# type
# train    743
# valid    133
# test     125
# Name: count, dtype: int64
# 100% 1001/1001 [00:28<00:00, 35.37it/s]
# Total performances (in segments):(3893, 1000, 7)
# Training performances: 5754
# Validation performances: 1060
# Test performances: 972
#
# ----------------Finished Processing--------------------

# %%
# !python main.py --mode train
# Out:
# usage: main.py [-h] [--mode {train,evaluate,predict}] [--data_path DATA_PATH]
#                [--num_of_features NUM_OF_FEATURES] [--num_of_performers NUM_OF_PERFORMERS]
#                [--cuda_devices CUDA_DEVICES [CUDA_DEVICES ...]] [--save_path SAVE_PATH]
#                [--ckpt_path CKPT_PATH] [--inference_path INFERENCE_PATH]
#
# options:
#   -h, --help            show this help message and exit
#   --mode {train,evaluate,predict}
#                         Chose to train or evaluate the model.
#   --data_path DATA_PATH
#                         Path to the processed data file '*.npz'.
#   --num_of_features NUM_OF_FEATURES
#                         Number of features used in the experiment
#   --num_of_performers NUM_OF_PERFORMERS
#                         Number of performers considered in the experiment
#   --cuda_devices CUDA_DEVICES [CUDA_DEVICES ...]
#                         CUDA device ids
#   --save_path SAVE_PATH
# ...

# %%
# !python -m pytorch_lightning.utilities.upgrade_checkpoint --map_to_cpu checkpoints/model_best_1000_7.ckpt
# Out:
# usage: upgrade_checkpoint.py [-h] [--extension EXTENSION] [--map-to-cpu] path
# upgrade_checkpoint.py: error: unrecognized arguments: --map_to_cpu

# %%
# !python main.py --mode evaluate --ckpt_path checkpoints/model_best_1000_7.ckpt
# Out:
# usage: main.py [-h] [--mode {train,evaluate,predict}] [--data_path DATA_PATH]
#                [--num_of_features NUM_OF_FEATURES] [--num_of_performers NUM_OF_PERFORMERS]
#                [--cuda_devices CUDA_DEVICES [CUDA_DEVICES ...]] [--save_path SAVE_PATH]
#                [--ckpt_path CKPT_PATH] [--inference_path INFERENCE_PATH]
#
# options:
#   -h, --help            show this help message and exit
#   --mode {train,evaluate,predict}
#                         Chose to train or evaluate the model.
#   --data_path DATA_PATH
#                         Path to the processed data file '*.npz'.
#   --num_of_features NUM_OF_FEATURES
#                         Number of features used in the experiment
#   --num_of_performers NUM_OF_PERFORMERS
#                         Number of performers considered in the experiment
#   --cuda_devices CUDA_DEVICES [CUDA_DEVICES ...]
#                         CUDA device ids
#   --save_path SAVE_PATH
# ...
